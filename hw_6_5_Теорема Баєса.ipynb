# %% [markdown]
# 1. У медичному центрі проводять тест на певну хворобу. Відомо, що 1% населення страждає на цю хворобу. Тест дає позитивний результат у 99% випадків для хворих і 5% випадків для здорових людей (хибнопозитивний результат). Якщо тест показав позитивний результат, яка ймовірність того, що людина насправді хвора?

# %%
p_of_ill = 0.01
p_of_healthy = 0.99
p_of_test_ill = 0.99
p_of_test_healthy = 0.05
p_of_test = (p_of_test_ill * p_of_ill) + (p_of_test_healthy * p_of_healthy)
p_of_ill_test = (p_of_test_ill * p_of_ill ) / p_of_test

f"{p_of_ill_test:.3f} - ймовірність того, що людина насправді хвора, якщо тест показав позитивний результат"
# Out:
# '0.167 - ймовірність того, що людина насправді хвора, якщо тест показав позитивний результат'

# %% [markdown]
# 2. У компанії 70% співробітників чесні, а 30% можуть інколи брехати. Детектор брехні правильно ідентифікує чесних співробітників у 90% випадків і неправильно класифікує їх як таких, що брехали, у 10% випадків. Якщо детектор показав, що співробітник брехав, яка ймовірність того, що він насправді брехав?

# %%
p_honest = 0.7
p_lying = 0.3
p_detector_lying = 0.9
p_detector_honest = 0.1
p_detector = p_detector_lying * p_lying + p_detector_honest * p_honest
p_lying_detector = p_detector_lying * p_lying / p_detector

f"{p_lying_detector:.3f} - ймовірність того, що співробітник насправді брехав, якщо детектор показав, що він брехав"
# Out:
# '0.794 - ймовірність того, що співробітник насправді брехав, якщо детектор показав, що він брехав'

# %% [markdown]
# 3. Відомо, що предмет можна загубити в одній з трьох кімнат: у першій кімнаті з ймовірністю 0,5, у другій — з ймовірністю 0,3, і в третій — з ймовірністю 0,2. Якщо предмет загублено в кімнаті, ймовірність знайти його під час пошуку складає 0,8 для першої кімнати, 0,6 для другої і 0,4 для третьої. Якщо предмет знайшли, яка ймовірність того, що його було загублено в першій кімнаті?

# %%
# А1, А2, А3 - подія, предмет загубили в одній із 3 кімнат
# В - подія, предмет знайти в одній із 3 кімнат

p_of_A1 = 0.5
p_of_A2 = 0.3
p_of_A3 = 0.2
p_of_B_A1 = 0.8
p_of_B_A2 = 0.6
p_of_B_A3 = 0.4
p_of_B = (p_of_B_A1 * p_of_A1) + (p_of_B_A2 * p_of_A2) + (p_of_B_A3 * p_of_A3)
p_of_A1_B = p_of_B_A1 * p_of_A1 / p_of_B

f"{p_of_A1_B:.3f} - ймовірність того, що знайдений предмет було загублено в першій кімнаті"
# Out:
# '0.606 - ймовірність того, що знайдений предмет було загублено в першій кімнаті'

# %% [markdown]
# 4. На заводі виробляють продукцію на трьох лініях: 50% продукції випускає перша лінія, 30% — друга, і 20% — третя. Відомо, що 2% продукції з першої лінії, 3% з другої і 5% з третьої мають дефекти. Якщо випадково обрана продукція має дефект, яка ймовірність того, що вона була випущена третьою лінією?

# %%
# А1, А2, А3 - подія, що продукцію виробляють на одній з трьох ліній
# D - продукція має дефект

p_of_A1 = 0.5
p_of_A2 = 0.3
p_of_A3 = 0.2
p_of_D_A1 = 0.02
p_of_D_A2 = 0.03
p_of_D_A3 = 0.05
p_of_D = (p_of_D_A1 * p_of_A1) + (p_of_D_A2 * p_of_A2) + (p_of_D_A3 * p_of_A3)
p_of_A3_D = (p_of_D_A3 * p_of_A3) / p_of_D

f"{p_of_A3_D:.3f} - ймовірність того, що випадково обрана продукція має дефект i була випущена третьою лінією"
# Out:
# '0.345 - ймовірність того, що випадково обрана продукція має дефект i була випущена третьою лінією'

# %% [markdown]
# 5. Програма для розпізнавання рукописних цифр має точність 95% для цифри "3" і 98% для інших цифр. Якщо на вхід програми подано цифру "3", а програма її не розпізнала, яка ймовірність того, що насправді була подана цифра "3"? Відомо, що в 20% випадків на вхід подається цифра "3".

# %%
# А - подія, що відображає подання цифр
# А3 - подія, що відображає подання цифри 3
# B - подія, що не розпізнала цифру

p_of_B_A3 = 1 - 0.95
p_of_B_A = 1 - 0.98
p_of_A3 = 0.2
p_of_A = 1 - p_of_A3
p_of_B = (p_of_B_A3 * p_of_A3) + (p_of_B_A * p_of_A)
p_of_A3_B = (p_of_B_A3 * p_of_A3) / p_of_B

f'Якщо на вхід програми подано цифру "3", а програма її не розпізнала, то з ймовірністю в {p_of_A3_B:.3f} це насправді була подана цифра "3'
# Out:
# 'Якщо на вхід програми подано цифру "3", а програма її не розпізнала, то з ймовірністю в 0.385 це насправді була подана цифра "3'
